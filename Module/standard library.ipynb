# %%
import array
arr=array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import random
print(random.randint(1,10))
print(random.choice(['apple','banana','cherry']))
# Out:
# 8
# apple

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\admin\Desktop\DS\1-Python bascis

# %%
os.mkdir('test_dir')

# %%
import shutil
shutil.copyfile('source.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
import json
data={'name':'krish','age':15}

json_str=json.dumps(data)
print(json_str)
print(type(json_str))
parsed_data=json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "krish", "age": 15}
# <class 'str'>
# {'name': 'krish', 'age': 15}
# <class 'dict'>

# %%
import csv

with open('example.csv',mode='w',newline='') as file:
    writer=csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['omkar',22])

with open('example.csv',mode='r') as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['omkar', '22']

# %%
import re

pattern='\d+'
text='there are 123 apples 456'
match=re.search(pattern,text)
print(match.group())
# Out:
# 123
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\admin\AppData\Local\Temp\ipykernel_2920\2903934844.py:3: SyntaxWarning: invalid escape sequence '\d'
#   pattern='\d+'
