# %%
def welcome():
    return "welcome tho course"

welcome()
# Out:
# 'welcome tho course'

# %%
wel=welcome
print(wel())
del welcome
print(wel())
# Out:
# welcome tho course
# welcome tho course

# %%
def main_welcome(msg):
    def sub_welcome_method():
        print("welcome to the course")
        print(msg)
        print("please learn the concept")
    return sub_welcome_method()

# %%
main_welcome("welcome everyone")
# Out:
# welcome to the course
# welcome everyone
# please learn the concept

# %%
def main_welcome(func):
    def sub_welcome_method():
        print("welcome to the course")
        func("welcome everyone")
        print("please learn the concept")
    return sub_welcome_method()

# %%
main_welcome(print)
# Out:
# welcome to the course
# welcome everyone
# please learn the concept

# %%
def main_welcome(func,lst):
    def sub_welcome_method():
        print("welcome to the course")
        print(func(lst))
        print("please learn the concept")
    return sub_welcome_method()

# %%
main_welcome(len,[1,2,3,4])
# Out:
# welcome to the course
# 4
# please learn the concept

# %%
def main_welcome(func):
    def sub_welcome_method():
        print("welcome to the course")
        func()
        print("please learn the concept")
    return sub_welcome_method()

# %%
def course_introduction():
    print("this is advance python course")

course_introduction()
# Out:
# this is advance python course

# %%
main_welcome(course_introduction)
# Out:
# welcome to the course
# this is advance python course
# please learn the concept

# %%
@main_welcome
def course_introduction():
    print("this is advance python course")
# Out:
# welcome to the course
# this is advance python course
# please learn the concept
