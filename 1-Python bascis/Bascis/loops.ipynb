# %%
for i in range(1,5):
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
for i in range(1,10,2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
str="omkar kadam"

for i in str:
    print(i)
# Out:
# o
# m
# k
# a
# r
#
# k
# a
# d
# a
# m

# %%
for i in range(10):
    if i==5:
        break
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(10):
    if(i%2==0):
        continue
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
n=10
sum=0
count=1

while count<=n:
    sum=sum+count
    count=count+1

print(sum)
# Out:
# 55

# %%
for num in range(1,20):
    if num>1:
        for i in range(2,num):
            if num%i==0:
                break
        else:
            print(num)
# Out:
# 2
# 3
# 5
# 7
# 11
# 13
# 17
# 19

# %%
number=int(input("enter a number"))
sum=0

while number!=0:
    num=number%10
    sum=sum+num
    number=number//10

print(sum)
# Out:
# 18
