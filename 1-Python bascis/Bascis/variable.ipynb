# %%
a=100

# %%
age=32
height=6.1
name="omkar"
is_student=True

print("age:",age)
# Out:
# age: 32

# %%
first_name="omkar"
last_name="Kadam"

# %%
age=25
height=6.1
name="omkar"
is_student=True
print(type(name))
# Out:
# <class 'str'>

# %%
age=25
print(type(age))

age_str=str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 25
# <class 'str'>

# %%
var=10
print(var,type(var))
# Out:
# 10 <class 'int'>

# %%
age=int(input("what is the age"))
print(age,type(age))
# Out:
# 23 <class 'int'>
