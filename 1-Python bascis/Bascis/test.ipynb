# %%
name="omkar"
Name="kadam"

print(name)
print(Name)
# Out:
# omkar
# kadam

# %%
age=32
if age>30:
    print(age)
# Out:
# 32

# %%
x=5;y=10;z=x+y
print(z)
# Out:
# 15

# %%
age=32
name="omkar"

# %%
type(age)
# Out:
# int

# %%
variable=10
print(type(variable))
variable="omkar"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 a=b
#
# NameError: name 'b' is not defined

# %%
if True:
    print("correct indentation")
    if False:
        print("this ont print")
    print("this will print or not")
print("outside the if block")
# Out:
# correct indentation
# this will print or not
# outside the if block
