# %%
empty_tuple=()
print(empty_tuple)
print(type(empty_tuple))
# Out:
# ()
# <class 'tuple'>

# %%
numbers=tuple([1,2,3,4,5,6])
numbers
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
mixed_tuple=(1,"hello world","omkar",3)
mixed_tuple
# Out:
# (1, 'hello world', 'omkar', 3)

# %%
numbers=tuple((1,2,3,4,5,6))
numbers
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
concatenation=numbers+mixed_tuple
print(concatenation)
# Out:
# (1, 2, 3, 4, 5, 6, 1, 'hello world', 'omkar', 3)

# %%
list=[1,2,3,4,5]
print(list)

list[1]="omkar"
print(list)
# Out:
# [1, 2, 3, 4, 5]
# [1, 'omkar', 3, 4, 5]

# %%
print(numbers.count(1))

# %%
packed_tuple=1,"hello",3.14
print(packed_tuple)
# Out:
# (1, 'hello', 3.14)

# %%
numbers=(1,2,3,4,5,6)
first,*middle,last=numbers
print(first)
print(middle)
print(last)
# Out:
# 1
# [2, 3, 4, 5]
# 6
