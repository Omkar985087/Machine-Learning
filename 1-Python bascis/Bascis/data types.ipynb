# %%
age=35
type(age)
# Out:
# int

# %%
height=5.11
print(height)
print(type(height))
# Out:
# 5.11
# <class 'float'>

# %%
a=10
b=10

a==b
# Out:
# True

# %%
result="hello"+str(5)
print(result)
# Out:
# hello5
