# %%
my_set={1,2,3,4,5}
print(my_set)
# Out:
# {1, 2, 3, 4, 5}

# %%
my_set=set([1,2,3,3,4,6,5,6])
print(my_set)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
my_set.discard(3)
print(my_set)
# Out:
# {1, 2, 4, 5, 6}

# %%
print(4 in my_set)
# Out:
# True

# %%
set1={1,2,3,4,5,6}
set2={4,5,6,7,8,9}
union_set=set1.intersection(set2)
print(union_set)
print(set1.difference(set2))
# Out:
# {4, 5, 6}
# {1, 2, 3}

# %%
text="in this tutorial we are discussing about sets"
words=text.split()

unique_words=set(words)
print(unique_words)
print(len(unique_words))
# Out:
# {'are', 'discussing', 'in', 'about', 'sets', 'this', 'tutorial', 'we'}
# 8
