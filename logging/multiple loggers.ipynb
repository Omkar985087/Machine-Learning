# %%
import logging

logger1=logging.getLogger("module1")
logger1.setLevel(logging.DEBUG)

logger2=logging.getLogger("module2")
logger2.setLevel(logging.WARNING)

logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s-%(name)s-%(levelname)s-%(message)s',
    datefmt='%Y-%m-%d %H:%M:%S'
)

# %%
logger1.debug("this is a debug message")
logger2.warning("this is a warnig message for module 2")
logger2.error("this is a error message")
# Out:
# 2025-10-09 10:20:09-module1-DEBUG-this is a debug message
# 2025-10-09 10:20:09-module2-WARNING-this is a warnig message for module 2
# 2025-10-09 10:20:09-module2-ERROR-this is a error message
