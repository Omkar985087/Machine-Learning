# %%
import os
new_directory="packages"
os.mkdir(new_directory)
print(f"directory'{new_directory}'created")
# Out:
# directory'packages'created

# %%
items=os.listdir('.')
print(items)
# Out:
# ['example.txt', 'file operation.ipynb', 'filepath.ipynb', 'packages']

# %%
dir_name="folder"
file_name="file.txt"
full_path=os.path.join(dir_name,file_name)
print(full_path)
# Out:
# folder\file.txt

# %%
dir_name="folder"
file_name="file.txt"
full_path=os.path.join(os.getcwd(),dir_name,file_name)
print(full_path)
# Out:
# c:\Users\admin\Desktop\DS\1-Python bascis\File Handling\folder\file.txt

# %%
path='example.txt'
if os.path.exists(path):
    print(f"the path '{path}' exists")
else:
    print(f"the path '{path}'does not exists")
# Out:
# the path 'example.txt' exists

# %%
relative_path='example.txt'
absolute_path=os.path.abspath(relative_path)
print(absolute_path)
# Out:
# c:\Users\admin\Desktop\DS\1-Python bascis\File Handling\example.txt
